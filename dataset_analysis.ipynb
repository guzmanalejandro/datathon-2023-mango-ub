# %% [markdown]
# # Data Analysis for the Fashion Compatibility Datathon
#
# We will perform some initial data analysis of both datasets `product_data.csv` and `outfit_data.csv`:

# %%
import pandas as pd
import numpy as np

# %%
# load both tables and explore its features
product_columns = ["cod_modelo_color","cod_color_code","des_color_specification_esp","des_agrup_color_eng","des_sex","des_age","des_line","des_fabric","des_product_category","des_product_aggregated_family","des_product_family","des_product_type","des_filename"]
outfit_columns = ["cod_outfit", "cod_modelo_color"]

product_data = pd.read_csv('./datathon/dataset/product_data.csv')
outfit_data = pd.read_csv('./datathon/dataset/outfit_data.csv')

# %%
product_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9222 entries, 0 to 9221
# Data columns (total 13 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   cod_modelo_color               9222 non-null   object
#  1   cod_color_code                 9222 non-null   object
#  2   des_color_specification_esp    9222 non-null   object
#  3   des_agrup_color_eng            9222 non-null   object
#  4   des_sex                        9222 non-null   object
#  5   des_age                        9222 non-null   object
#  6   des_line                       9222 non-null   object
#  7   des_fabric                     9222 non-null   object
#  8   des_product_category           9222 non-null   object
#  9   des_product_aggregated_family  9222 non-null   object
#  10  des_product_family             9222 non-null   object
#  11  des_product_type               9222 non-null   object
#  12  des_filename                   9222 non-null   object
# dtypes: object(13)
# memory usage: 936.7+ KB

# %%
product_data.value_counts(['des_line', 'des_sex', 'des_age'])
# Out:
# des_line  des_sex  des_age
# SHE       Female   Adult      9144
# HOME      Unisex   Adult        50
# KIDS      Female   Kids         19
# VIOLETA   Female   Adult         7
# HE        Male     Adult         2
# Name: count, dtype: int64

# %%
product_data.value_counts(['des_fabric'])
# Out:
# des_fabric
# P-PLANA           3041
# C-COMPLEMENTOS    2569
# K-CIRCULAR        1564
# T-TRICOT          1274
# J-JEANS            606
# O-POLIPIEL          97
# L-PIEL              71
# Name: count, dtype: int64

# %%
merged_data = pd.merge(outfit_data, product_data)
merged_data
# Out:
#        cod_outfit cod_modelo_color cod_color_code des_color_specification_esp  \
# 0               1      51000622-02             02                    OFFWHITE
# 1            2086      51000622-02             02                    OFFWHITE
# 2               1      43067759-01             01                      BLANCO
# 3             145      43067759-01             01                      BLANCO
# 4             626      43067759-01             01                      BLANCO
# ...           ...              ...            ...                         ...
# 43577        7497      57041183-06             06                      PIEDRA
# 43578        7085      57074425-08             08                       BEIGE
# 43579        7497      57074425-08             08                       BEIGE
# 43580        7373      57089203-99             99                       NEGRO
# 43581        7373      67070595-99             99                       NEGRO
#
#       des_agrup_color_eng des_sex des_age des_line  des_fabric  \
# 0                   WHITE  Female   Adult      SHE  K-CIRCULAR
# 1                   WHITE  Female   Adult      SHE  K-CIRCULAR
# 2                   WHITE  Female   Adult      SHE     P-PLANA
# 3                   WHITE  Female   Adult      SHE     P-PLANA
# 4                   WHITE  Female   Adult      SHE     P-PLANA
# ...                   ...     ...     ...      ...         ...
# 43577               WHITE  Unisex   Adult     HOME     P-PLANA
# 43578               WHITE  Unisex   Adult     HOME     P-PLANA
# 43579               WHITE  Unisex   Adult     HOME     P-PLANA
# 43580                GREY  Female   Adult      SHE     P-PLANA
# 43581                GREY  Female   Adult      SHE     P-PLANA
#
#       des_product_category des_product_aggregated_family des_product_family  \
# 0                     Tops                          Tops               Tops
# 1                     Tops                          Tops               Tops
# 2                  Bottoms             Skirts and shorts             Skirts
# 3                  Bottoms             Skirts and shorts             Skirts
# 4                  Bottoms             Skirts and shorts             Skirts
# ...                    ...                           ...                ...
# 43577                 Home                         Decor      Deco Textiles
# 43578                 Home                         Decor      Deco Textiles
# 43579                 Home                         Decor      Deco Textiles
# 43580                 Tops                          Tops               Tops
# 43581              Bottoms           Trousers & leggings           Trousers
#
#       des_product_type                          des_filename
# 0                  Top  datathon/images/2019_51000622_02.jpg
# 1                  Top  datathon/images/2019_51000622_02.jpg
# 2                Skirt  datathon/images/2019_43067759_01.jpg
# 3                Skirt  datathon/images/2019_43067759_01.jpg
# 4                Skirt  datathon/images/2019_43067759_01.jpg
# ...                ...                                   ...
# 43577          Curtain  datathon/images/2023_57041183_06.jpg
# 43578      Carpet Yarn  datathon/images/2023_57074425_08.jpg
# 43579      Carpet Yarn  datathon/images/2023_57074425_08.jpg
# 43580              Top  datathon/images/2019_57089203_99.jpg
# 43581         Trousers  datathon/images/2020_67070595_99.jpg
#
# [43582 rows x 14 columns]

# %%
outfit_data.groupby('cod_outfit').count().value_counts().sort_index()
# Out:
# cod_modelo_color
# 2                     30
# 3                    142
# 4                    758
# 5                   3875
# 6                   1737
# 7                    674
# 8                    309
# 9                    174
# 10                    95
# 11                    26
# 12                    13
# 13                     8
# 15                     1
# Name: count, dtype: int64

# %% [markdown]
# ### Trying to apply ARL
# https://medium.com/mlearning-ai/recommendation-systems-arl-association-rule-learning-bed1a07b5d9a

# %%
# Get the COLOR counts for each outfit
# pivot_outfit_colors = pd.pivot_table(merged_data[['cod_outfit', 'cod_color_code', 'des_agrup_color_eng']], index=['cod_outfit'], columns=['des_agrup_color_eng'], aggfunc="count", fill_value = 0.0)
outfit_color_counts = merged_data.groupby(['cod_outfit', 'des_agrup_color_eng'])['des_agrup_color_eng'].count().unstack().fillna(0).map(lambda x: x > 0.0)
outfit_color_counts
# Out:
# des_agrup_color_eng   BLUE  BROWN  GREEN   GREY  ORANGE   PINK  PURPLE    RED  \
# cod_outfit
# 1                    False  False  False  False   False  False   False  False
# 2                    False  False  False  False   False  False   False  False
# 3                     True  False  False   True   False  False   False   True
# 4                     True  False  False  False   False   True   False  False
# 5                    False   True  False   True   False  False   False  False
# ...                    ...    ...    ...    ...     ...    ...     ...    ...
# 7838                 False   True  False   True   False  False   False  False
# 7839                 False   True  False   True   False  False   False  False
# 7840                 False  False  False   True   False  False   False  False
# 7841                 False  False   True   True   False  False   False  False
# 7842                  True  False  False   True   False  False   False  False
#
# des_agrup_color_eng  WHITE  YELLOW
# cod_outfit
# 1                     True   False
# 2                     True   False
# 3                     True   False
# 4                     True    True
# 5                     True   False
# ...                    ...     ...
# 7838                  True   False
# 7839                  True   False
# 7840                  True   False
# 7841                  True   False
# 7842                  True   False
#
# [7842 rows x 10 columns]

# %%
from mlxtend.frequent_patterns import apriori, association_rules

outfit_frequent_colors = apriori(outfit_color_counts, min_support=0.01, use_colnames=True).sort_values("support", ascending=False)
outfit_frequent_colors
# Out:
#      support                   itemsets
# 8   0.849656                    (WHITE)
# 3   0.768426                     (GREY)
# 31  0.627008              (GREY, WHITE)
# 1   0.308977                    (BROWN)
# 0   0.284239                     (BLUE)
# ..       ...                        ...
# 35  0.011859            (PURPLE, WHITE)
# 40  0.011222        (BLUE, GREY, GREEN)
# 61  0.010967  (BLUE, GREY, WHITE, PINK)
# 13  0.010457             (BLUE, ORANGE)
# 62  0.010457   (BLUE, GREY, RED, WHITE)
#
# [64 rows x 2 columns]

# %%
outfit_color_rules = association_rules(outfit_frequent_colors, metric="support", min_threshold=0.01)
outfit_interesting_rules = outfit_color_rules[
	(outfit_color_rules["support"] > 0.1)
    & (outfit_color_rules["confidence"] > 0.1)
    #& (outfit_color_rules["leverage"] > 1)
].sort_values(['confidence', 'support', 'lift'], ascending=False)
outfit_interesting_rules
# Out:
#        antecedents     consequents  antecedent support  consequent support  \
# 2          (BROWN)         (WHITE)            0.308977            0.849656
# 10   (BROWN, GREY)         (WHITE)            0.199821            0.849656
# 4           (BLUE)         (WHITE)            0.284239            0.849656
# 16    (BLUE, GREY)         (WHITE)            0.210916            0.849656
# 0           (GREY)         (WHITE)            0.768426            0.849656
# 6           (BLUE)          (GREY)            0.284239            0.768426
# 1          (WHITE)          (GREY)            0.849656            0.768426
# 17   (BLUE, WHITE)          (GREY)            0.244453            0.768426
# 8          (BROWN)          (GREY)            0.308977            0.768426
# 11  (BROWN, WHITE)          (GREY)            0.281943            0.768426
# 19          (BLUE)   (GREY, WHITE)            0.284239            0.627008
# 13         (BROWN)   (GREY, WHITE)            0.308977            0.627008
# 3          (WHITE)         (BROWN)            0.849656            0.308977
# 5          (WHITE)          (BLUE)            0.849656            0.284239
# 12   (GREY, WHITE)         (BROWN)            0.627008            0.308977
# 18   (GREY, WHITE)          (BLUE)            0.627008            0.284239
# 7           (GREY)          (BLUE)            0.768426            0.284239
# 9           (GREY)         (BROWN)            0.768426            0.308977
# 14          (GREY)  (BROWN, WHITE)            0.768426            0.281943
# 20          (GREY)   (BLUE, WHITE)            0.768426            0.244453
# 15         (WHITE)   (BROWN, GREY)            0.849656            0.199821
# 21         (WHITE)    (BLUE, GREY)            0.849656            0.210916
#
#      support  confidence      lift  leverage  conviction  zhangs_metric
# 2   0.281943    0.912505  1.073971  0.019419    1.718322       0.099672
# 10  0.175083    0.876197  1.031237  0.005303    1.214379       0.037855
# 4   0.244453    0.860027  1.012206  0.002948    1.074094       0.016848
# 16  0.174318    0.826481  0.972725 -0.004888    0.866444      -0.034315
# 0   0.627008    0.815964  0.960347 -0.025889    0.816929      -0.151323
# 6   0.210916    0.742037  0.965658 -0.007501    0.897700      -0.047335
# 1   0.627008    0.737956  0.960347 -0.025889    0.883720      -0.215464
# 17  0.174318    0.713093  0.927992 -0.013526    0.807139      -0.093136
# 8   0.199821    0.646719  0.841615 -0.037605    0.655494      -0.214046
# 11  0.175083    0.620986  0.808127 -0.041570    0.610989      -0.248491
# 19  0.174318    0.613279  0.978104 -0.003902    0.964499      -0.030327
# 13  0.175083    0.566653  0.903741 -0.018648    0.860722      -0.133552
# 3   0.281943    0.331833  1.073971  0.019419    1.034206       0.458120
# 5   0.244453    0.287708  1.012206  0.002948    1.004871       0.080210
# 12  0.175083    0.279235  0.903741 -0.018648    0.958735      -0.222130
# 18  0.174318    0.278015  0.978104 -0.003902    0.991380      -0.056619
# 7   0.210916    0.274477  0.965658 -0.007501    0.986546      -0.133129
# 9   0.199821    0.260040  0.841615 -0.037605    0.933865      -0.448327
# 14  0.175083    0.227846  0.808127 -0.041570    0.929940      -0.506243
# 20  0.174318    0.226850  0.927992 -0.013526    0.977233      -0.250982
# 15  0.175083    0.206063  1.031237  0.005303    1.007862       0.201477
# 21  0.174318    0.205163  0.972725 -0.004888    0.992762      -0.157188
